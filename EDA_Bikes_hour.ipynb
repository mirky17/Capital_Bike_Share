# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set()
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# import DS
hour = pd.read_csv('hour.csv', sep= ',')
hour.tail()
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 17374           1           2  0.26  0.2576  0.60     0.1642      11
# 17375           1           2  0.26  0.2576  0.60     0.1642       8
# 17376           1           1  0.26  0.2576  0.60     0.1642       7
# 17377           1           1  0.26  0.2727  0.56     0.1343      13
# 17378           1           1  0.26  0.2727  0.65     0.1343      12
#
#        registered  cnt
# 17374         108  119
# 17375          81   89
# 17376          83   90
# 17377          48   61
# 17378          37   49

# %%
hour.shape
# Out:
# (17379, 17)

# %%
hour.drop('instant',axis=1,inplace=True)

# %%
hour1 = hour.rename(columns={'dteday': 'date', 'yr': 'year','mnth':'month','hr':'hour' ,'temp':'temperature', 'atemp':'temp_feeling', 'hum':'humidity','windspeed':'wind_speed','cnt':'count'} , inplace=True)

# %%
hour.head()
# Out:
#          date  season  year  month  hour  holiday  weekday  workingday  \
# 0  2011-01-01       1     0      1     0        0        6           0
# 1  2011-01-01       1     0      1     1        0        6           0
# 2  2011-01-01       1     0      1     2        0        6           0
# 3  2011-01-01       1     0      1     3        0        6           0
# 4  2011-01-01       1     0      1     4        0        6           0
#
#    weathersit  temperature  temp_feeling  humidity  wind_speed  casual  \
# 0           1         0.24        0.2879      0.81         0.0       3
# 1           1         0.22        0.2727      0.80         0.0       8
# 2           1         0.22        0.2727      0.80         0.0       5
# 3           1         0.24        0.2879      0.75         0.0       3
# 4           1         0.24        0.2879      0.75         0.0       0
#
#    registered  count
# 0          13     16
# 1          32     40
# 2          27     32
# ...

# %%
hour.dtypes
# Out:
# date             object
# season            int64
# year              int64
# month             int64
# hour              int64
# holiday           int64
# weekday           int64
# workingday        int64
# weathersit        int64
# temperature     float64
# temp_feeling    float64
# humidity        float64
# wind_speed      float64
# casual            int64
# registered        int64
# count             int64
# dtype: object

# %%
hour['temp_Cel'] = hour['temperature'] * 47-8

# %%
hour['temp_Cel']=hour['temp_Cel'].astype(int)

# %%
hour.describe()
# Out:
#              season          year         month          hour       holiday  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       2.501640      0.502561      6.537775     11.546752      0.028770
# std        1.106918      0.500008      3.438776      6.914405      0.167165
# min        1.000000      0.000000      1.000000      0.000000      0.000000
# 25%        2.000000      0.000000      4.000000      6.000000      0.000000
# 50%        3.000000      1.000000      7.000000     12.000000      0.000000
# 75%        3.000000      1.000000     10.000000     18.000000      0.000000
# max        4.000000      1.000000     12.000000     23.000000      1.000000
#
#             weekday    workingday    weathersit   temperature  temp_feeling  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       3.003683      0.682721      1.425283      0.496987      0.475775
# ...
